# %% [markdown]
# # [Chapter 9](https://learning.oreilly.com/library/view/python-machine-learning/9781119545637/c09.xhtml): Supervised Learning - Classification using K-Nearest Neighbors (KNN)
#
# > ![](https://learning.oreilly.com/covers/urn:orm:book:9781119545637/200w/)
#
# > [*Python Machine Learning*](https://learning.oreilly.com/library/view/python-machine-learning/9781119545637/), W.-M. Lee, 2019, Wiley.

# %% [markdown]
# ## Overview
#
# *K-Nearest Neighbors (KNN)* is a simple instance-based algorithm that "memorizes" all the training samples as they are positioned in hyperspace. During testing (or prediction):
#
# 1.   the algorithm compares the query instance's distance to all the training samples;
# 2.   selects the $K$-nearest neighbors (hence the name) to the query instance; and
# 3.   takes the majority class represented by the $K$-nearest neighbors to be the prediction for the query instance.
#
# Clearly, the crucial part of the algorithm is Step #2 above - how can we efficiently compare distances in a multidimensional hyperplane to determine the $K$-nearest neighbors to the query instance?

# %% [markdown]
# ## Implementing KNN in Python

# %%
import pandas as pd
import numpy as np
import operator
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://www.ecst.csuchico.edu/~bjuliano/csci581/datasets/knn.csv")
print(data)

sns.lmplot( x='x' , y='y' ,
            data=data ,
            hue='c' ,
            palette='Set1' ,
            fit_reg=False ,
            scatter_kws={"s": 70}
           )
plt.show()
# Out:
#    x  y  c
# 0  1  1  A
# 1  2  2  A
# 2  4  3  B
# 3  3  3  A
# 4  3  5  B
# 5  5  6  B
# 6  5  4  B

# %% [markdown]
# ## Calculating the Distance Between the Points
#
# We will use [*Euclidian* distance](https://en.wikipedia.org/wiki/Euclidean_distance) to calculate the distance between points. Recall that the *distance formula* between two points, $p=(x_1,y_1)$ and $q=(x_2,y_2)$, in the Euclidian plane is given by
#
# $${\sf distance}(p,q) ~=~ \sqrt{~(x_1 - x_2)^2 + (y_1 - y_2)^2~~}$$
#
# Note that this equation can be generalized to any dimension.

# %%
#---to calculate the distance between two points---
def euclidean_distance(pt1, pt2, dimension):
    distance = 0
    for x in range(dimension):
        distance += np.square(pt1[x] - pt2[x])
    return np.sqrt(distance)

# %% [markdown]
# Scikit-Learn's [`DistanceMetric`](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.DistanceMetric.html) class provides other fast distance metric functions.

# %% [markdown]
# ### Implementing KNN

# %%
#---our own KNN model---
def knn(training_points, test_point, k):
    distances = {}

    #---the number of axes we are dealing with---
    dimension = test_point.shape[1]

    #--calculating euclidean distance between each
    # point in the training data and test data
    for x in range(len(training_points)):
        dist = euclidean_distance(test_point, training_points.iloc[x], dimension)
        #---record the distance for each training points---
        distances[x] = dist[0]

    #---sort the distances--- See https://docs.python.org/3/library/operator.html
    sorted_d = sorted(distances.items(), key=operator.itemgetter(1))

    #---to store the neighbors---
    neighbors = []

    #---extract the top k neighbors---
    for x in range(k):
        neighbors.append(sorted_d[x][0])

    #---for each neighbor found, find out its class---
    class_counter = {}
    for x in range(len(neighbors)):
        #---find out the class for that particular point---
        cls = training_points.iloc[neighbors[x]][-1]
        if cls in class_counter:
            class_counter[cls] += 1
        else:
            class_counter[cls] = 1

    #---sort the class_counter in descending order---
    sorted_counter = sorted(class_counter.items(), key=operator.itemgetter(1),
                           reverse=True)

    #---return the class with the most count, as well as the neighbors found---
    return(sorted_counter[0][0], neighbors)

# %% [markdown]
# ### Making Predictions

# %%
#---test point---
test_set = [[3,3.9]]
test = pd.DataFrame(test_set)
cls,neighbors = knn(data, test, 5)

# Show results
print("Given:", test_set)
print("\nNeighbors:")
print(data.iloc[neighbors])
print("\nPredicted Class:", cls)
# Out:
# Given: [[3, 3.9]]
#
# Neighbors:
#    x  y  c
# 3  3  3  A
# 4  3  5  B
# 2  4  3  B
# 6  5  4  B
# 1  2  2  A
#
# Predicted Class: B

# %% [markdown]
# ### Visualizing Different Values of K

# %%
#---generate the color map for the scatter plot---
#---if column 'c' is A, then use Red, else use Blue---
colors = ['r' if i == 'A' else 'b'  for i in data['c']]
ax = data.plot(kind='scatter', x='x', y='y', c = colors)
plt.xlim(0,7)
plt.ylim(0,7)

#---plot the test point---
plt.plot(test_set[0][0],test_set[0][1], "yo", markersize='9')

print("Given:", test_set)
for k in range(7,0,-2):
    cls,neighbors = knn(data, test, k)
    print("\n============")
    print("k =", k)
    print("Neighbors:")
    print(data.iloc[neighbors])
    print("Predicted Class:", cls)

    furthest_point = data.iloc[neighbors].tail(1)

    #---draw a circle connecting the test point and the furthest point---
    radius = euclidean_distance(test, furthest_point.iloc[0], 2)

    #---display the circle in red if classification is A,
    # else display circle in blue---
    c = 'r' if cls=='A' else 'b'
    circle = plt.Circle((test_set[0][0], test_set[0][1]),
                        radius, color=c, alpha=0.3)
    ax.add_patch(circle)
print()

plt.gca().set_aspect('equal', adjustable='box')
plt.show()
# Out:
# Given: [[3, 3.9]]
#
# ...
# k = 7
# Neighbors:
#    x  y  c
# 3  3  3  A
# 4  3  5  B
# 2  4  3  B
# 6  5  4  B
# 1  2  2  A
# 5  5  6  B
# 0  1  1  A
# Predicted Class: B
#
# ...
# k = 5
# Neighbors:
#    x  y  c
# 3  3  3  A
# 4  3  5  B
# 2  4  3  B
# 6  5  4  B
# 1  2  2  A
# Predicted Class: B
#
# ...
# k = 3
# Neighbors:
#    x  y  c
# 3  3  3  A
# 4  3  5  B
# 2  4  3  B
# Predicted Class: B
#
# ...
# k = 1
# Neighbors:
#    x  y  c
# 3  3  3  A
# Predicted Class: A

# %% [markdown]
# ## Using Scikit-Learn’s [`KNeighborsClassifier`](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html) class for KNN
#
# See in the documentation for the [`sklearn.neighbors`](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.neighbors) Nearest Neighbors module for additional information and functionality.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
from sklearn import svm, datasets
import matplotlib.pyplot as plt

iris = datasets.load_iris()

X = iris.data[:, :2]       #  take the first two features
y = iris.target

#---plot the points---
colors = ['red', 'green', 'blue']
for color, i, target in zip(colors, [0, 1, 2], iris.target_names):
    plt.scatter(X[y==i, 0], X[y==i, 1], color=color, label=target)

plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.legend(loc='best', shadow=False, scatterpoints=1)

plt.title('Scatter plot of Sepal width against Sepal length')
plt.show()

# %% [markdown]
# ### Exploring Different Values of $K$
#
# **Note:** The `metric` parameter of the [`KNeighborsClassifier`](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html) class ties in with the [`DistanceMetric`](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.DistanceMetric.html) class for flexibility in deciding ways to measure distance.

# %%
from sklearn.neighbors import KNeighborsClassifier

k = 1
#---instantiate learning model---
knn = KNeighborsClassifier(n_neighbors=k)

#---fitting the model---
knn.fit(X, y)

#---min and max for the first feature---
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
print(f'Sepal Length min: {x_min}, Sepal Length max: {x_max}')

#---min and max for the second feature---
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

#---step size in the mesh---
h = (x_max / x_min)/100

#---make predictions for each of the points in xx,yy---
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])

#---draw the result using a color plot---
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Accent, alpha=0.8)

#---plot the training points---
colors = ['red', 'green', 'blue']
for color, i, target in zip(colors, [0, 1, 2], iris.target_names):
    plt.scatter(X[y==i, 0], X[y==i, 1], color=color, label=target)

plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title(f'KNN (k={k})')
plt.legend(loc='best', shadow=False, scatterpoints=1)

predictions = knn.predict(X)

#--classifications based on predictions---
print(np.unique(predictions, return_counts=True))
# Out:
# Sepal Length min: 3.3, Sepal Length max: 8.9
# (array([0, 1, 2]), array([50, 56, 44]))

# %% [markdown]
# ### Parameter-Tuning $K$ via 10-fold cross validation

# %%
from sklearn.model_selection import cross_val_score

#---holds the cv (cross-validates) scores---
cv_scores = []

#---use all features---
X = iris.data[:, :4]
y = iris.target

#---number of folds---
folds = 10

#---creating odd list of K for KNN---
ks = list(range(1,int(len(X) * ((folds - 1)/folds))))

#---remove all multiples of 3---
ks = [k for k in ks if k % 3 != 0]

#---perform k-fold cross validation---
for k in ks:
    knn = KNeighborsClassifier(n_neighbors=k)

    #---performs cross-validation and returns the average accuracy---
    scores = cross_val_score(knn, X, y, cv=folds, scoring='accuracy')
    mean = scores.mean()
    cv_scores.append(mean)
    print(k, mean)
# Out:
# 1 0.96
# 2 0.9533333333333334
# 4 0.9666666666666666
# 5 0.9666666666666668
# 7 0.9666666666666668
# 8 0.9666666666666668
# 10 0.9666666666666668
# 11 0.9666666666666668
# 13 0.9800000000000001
# 14 0.9733333333333334
# 16 0.9733333333333334
# 17 0.9733333333333334
# 19 0.9733333333333334
# 20 0.9800000000000001
# 22 0.9666666666666666
# 23 0.9733333333333334
# 25 0.9666666666666666
# 26 0.96
# 28 0.9533333333333334
# 29 0.9533333333333334
# 31 0.9466666666666667
# 32 0.9466666666666667
# 34 0.9466666666666667
# 35 0.9466666666666667
# 37 0.9466666666666667
# 38 0.9466666666666667
# 40 0.9533333333333334
# 41 0.9533333333333334
# 43 0.9466666666666667
# 44 0.9400000000000001
# 46 0.9333333333333333
# 47 0.9333333333333333
# 49 0.9400000000000001
# 50 0.9266666666666667
# 52 0.9333333333333333
# 53 0.9333333333333333
# 55 0.9333333333333333
# 56 0.9066666666666666
# 58 0.9133333333333334
# 59 0.9200000000000002
# 61 0.9199999999999999
# 62 0.9066666666666666
# 64 0.9
# 65 0.9
# ...

# %% [markdown]
# ### Finding the Optimal value for $K$

# %%
#---calculate misclassification error for each k---
MSE = [1 - x for x in cv_scores]

#---determining best k (min. MSE)---
optimal_k = ks[MSE.index(min(MSE))]
print(f"The optimal number of neighbors is {optimal_k}")

#---plot misclassification error vs k---
plt.plot(ks, MSE)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Misclassification Error')
plt.show()
# Out:
# The optimal number of neighbors is 13
